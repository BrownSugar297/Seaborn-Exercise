# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = sns.load_dataset("tips")

a = sns.FacetGrid(data, col="day")
plt.show()

# %%
a = sns.FacetGrid(data, col="smoker",height=2)
plt.show()

# %%
a = sns.FacetGrid(data, col="smoker",height=2)
a.map(sns.scatterplot,"day","tip")
plt.show()

# %%
a = sns.FacetGrid(data, col="time",height=2,hue="sex")
a.map(sns.barplot,"day","tip")
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
