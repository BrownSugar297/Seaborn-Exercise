# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
plt.show()

# %%
sns.heatmap(glue, annot=True)
plt.show()

# %%
data=sns.load_dataset("tips")
gb=data.groupby("day").agg({"tip":"mean"})
sns.heatmap(gb)
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_10228\1557944180.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb=data.groupby("day").agg({"tip":"mean"})

# %%
data=pd.read_excel("ESD.xlsx")
gb=data.groupby("Job Title").agg({"Annual Salary":"mean"})
sns.heatmap(gb)
plt.show()
