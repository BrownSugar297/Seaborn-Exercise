# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = sns.load_dataset("tips")

sns.boxplot(data=data,x="tip")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = sns.load_dataset("tips")

sns.boxplot(data=data,x="day",y="tip",orient="vertical",fliersize=10)
plt.show()
