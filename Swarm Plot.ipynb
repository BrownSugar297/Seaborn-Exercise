# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("tips")

sns.swarmplot(data=data,x="day",y="total_bill",hue="sex",dodge=2)
plt.show()

# %%
sns.stripplot(data=data,x="day",y="total_bill",hue="sex",jitter=.3)
plt.show()
